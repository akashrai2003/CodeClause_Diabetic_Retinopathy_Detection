# %%
import numpy as np
from keras.applications import MobileNet
from keras.applications.mobilenet import preprocess_input
import keras
from keras import backend as K
from keras.layers.core import Dense,Dropout
from keras.layers import GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt

# %%
train_path='base_dir/train_dir'
valid_path='base_dir/val_dir'

num_train_samples=32247
num_val_samples=3511
train_batch_size=10
val_batch_size=10
image_size=224

# %%
train_steps=np.ceil(num_train_samples/train_batch_size)
val_steps=np.ceil(num_val_samples/val_batch_size)

# %%
print(train_steps)
print(val_steps)
# Out:
# 3225.0
# 352.0

# %%
training_batches=ImageDataGenerator(
    preprocessing_function=\
    keras.applications.mobilenet.preprocess_input).flow_from_directory(
        train_path,
        target_size=(image_size,image_size),
        batch_size=train_batch_size
    )
# Out:
# Found 32247 images belonging to 5 classes.

# %%
validation_batches=ImageDataGenerator(
    preprocessing_function=\
    keras.applications.mobilenet.preprocess_input).flow_from_directory(
        valid_path,
        target_size=(image_size,image_size),
        batch_size=val_batch_size
    )

test_batches=ImageDataGenerator(
    preprocessing_function=\
    keras.applications.mobilenet.preprocess_input).flow_from_directory(
        valid_path,
        target_size=(image_size,image_size),
        batch_size=val_batch_size,
        shuffle=False
    )
# Out:
# Found 3511 images belonging to 5 classes.
# Found 3511 images belonging to 5 classes.

# %%
mobile=keras.applications.mobilenet.MobileNet()

# %%
mobile.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1, 1, 1024)       0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  conv_preds (Conv2D)         (None, 1, 1, 1000)        1025000
#
#  reshape_2 (Reshape)         (None, 1000)              0
#
#  predictions (Activation)    (None, 1000)              0
#
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
#for creating our custom model using mobilenet we will remmove last five layers from the model
# as they are used for a different i.e. base model for mobilenet
x=mobile.layers[-6].output
x=Dropout(0.25)(x)
x=GlobalAveragePooling2D()(x)
predictions=Dense(5,activation='softmax')(x)

model=Model(inputs=mobile.input,outputs=predictions)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  dropout (Dropout)           (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                 5125
#
# =================================================================
# Total params: 3,233,989
# Trainable params: 3,212,101
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
for layer in model.layers[:-23]:
    layer.trainable=False

# %%
from keras.metrics import categorical_accuracy,top_k_categorical_accuracy

# %%
def top_3_accuracy(y_true,y_pred):
    return top_k_categorical_accuracy(y_true,y_pred,k=3)
def top_2_accuracy(y_true,y_pred):
    return top_k_categorical_accuracy(y_true,y_pred,k=2)

# %%
model.compile(Adam(learning_rate=0.01),loss='categorical_crossentropy',metrics=[categorical_accuracy,top_2_accuracy,top_3_accuracy])

# %%
#we are defining our own weights for the model and not using imagenet weights
#to do that we divide each class's number of images with the highest number of images present
# Ex: 23222/23222 and 23222/2194 and so on
class_weights={
    0: 1.0,
    1: 10.0,
    2: 4.0,
    3: 22.0,
    4: 22.0,
}

# %%
filepath="model.h5"

# %%
checkpoint=ModelCheckpoint(filepath,monitor='val_top_3_accuracy',
                           verbose=1,save_best_only=True,mode='max',
                           min_lr=0.00001)
reduce_lr=ReduceLROnPlateau(monitor='val_top_3_accuracy',
                            factor=0.5,patience=2,verbose=1,
                            mode='max',min_lr=0.00001)
callbacks_list=[checkpoint,reduce_lr]

# %%
history=model.fit_generator(training_batches,
                           steps_per_epoch=train_steps,
                           class_weight=class_weights,
                           validation_data=validation_batches,
                           validation_steps=val_steps,
                           epochs=30,
                           verbose=1,
                           callbacks=callbacks_list)
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_4024\2376756131.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(training_batches,
# Epoch 1/30
# 3225/3225 [==============================] - ETA: 0s - loss: 4.9364 - categorical_accuracy: 0.3514 - top_2_accuracy: 0.6864 - top_3_accuracy: 0.8623
# Epoch 1: val_top_3_accuracy improved from -inf to 0.95956, saving model to model.h5
# 3225/3225 [==============================] - 1387s 429ms/step - loss: 4.9364 - categorical_accuracy: 0.3514 - top_2_accuracy: 0.6864 - top_3_accuracy: 0.8623 - val_loss: 1.2637 - val_categorical_accuracy: 0.1467 - val_top_2_accuracy: 0.8189 - val_top_3_accuracy: 0.9596 - lr: 0.0100
# Epoch 2/30
# 3225/3225 [==============================] - ETA: 0s - loss: 4.3495 - categorical_accuracy: 0.3852 - top_2_accuracy: 0.7246 - top_3_accuracy: 0.8910
# Epoch 2: val_top_3_accuracy improved from 0.95956 to 0.96696, saving model to model.h5
# 3225/3225 [==============================] - 1342s 416ms/step - loss: 4.3495 - categorical_accuracy: 0.3852 - top_2_accuracy: 0.7246 - top_3_accuracy: 0.8910 - val_loss: 0.8146 - val_categorical_accuracy: 0.7405 - val_top_2_accuracy: 0.8473 - val_top_3_accuracy: 0.9670 - lr: 0.0100
# Epoch 3/30
# 3225/3225 [==============================] - ETA: 0s - loss: 4.1833 - categorical_accuracy: 0.4007 - top_2_accuracy: 0.7340 - top_3_accuracy: 0.9048
# Epoch 3: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 1303s 404ms/step - loss: 4.1833 - categorical_accuracy: 0.4007 - top_2_accuracy: 0.7340 - top_3_accuracy: 0.9048 - val_loss: 1.6931 - val_categorical_accuracy: 0.2287 - val_top_2_accuracy: 0.5013 - val_top_3_accuracy: 0.7502 - lr: 0.0100
# Epoch 4/30
# 3225/3225 [==============================] - ETA: 0s - loss: 4.2095 - categorical_accuracy: 0.4010 - top_2_accuracy: 0.7351 - top_3_accuracy: 0.9090
# Epoch 4: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 3225/3225 [==============================] - 938s 291ms/step - loss: 4.2095 - categorical_accuracy: 0.4010 - top_2_accuracy: 0.7351 - top_3_accuracy: 0.9090 - val_loss: 1.0488 - val_categorical_accuracy: 0.5263 - val_top_2_accuracy: 0.8220 - val_top_3_accuracy: 0.9536 - lr: 0.0100
# Epoch 5/30
# 3225/3225 [==============================] - ETA: 0s - loss: 3.8035 - categorical_accuracy: 0.4188 - top_2_accuracy: 0.7735 - top_3_accuracy: 0.9263
# Epoch 5: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 959s 297ms/step - loss: 3.8035 - categorical_accuracy: 0.4188 - top_2_accuracy: 0.7735 - top_3_accuracy: 0.9263 - val_loss: 1.7374 - val_categorical_accuracy: 0.1481 - val_top_2_accuracy: 0.4363 - val_top_3_accuracy: 0.7103 - lr: 0.0050
# Epoch 6/30
# 3225/3225 [==============================] - ETA: 0s - loss: 3.7070 - categorical_accuracy: 0.4129 - top_2_accuracy: 0.7807 - top_3_accuracy: 0.9336
# Epoch 6: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 3225/3225 [==============================] - 967s 300ms/step - loss: 3.7070 - categorical_accuracy: 0.4129 - top_2_accuracy: 0.7807 - top_3_accuracy: 0.9336 - val_loss: 1.1416 - val_categorical_accuracy: 0.6004 - val_top_2_accuracy: 0.8297 - val_top_3_accuracy: 0.9490 - lr: 0.0050
# Epoch 7/30
# 3225/3225 [==============================] - ETA: 0s - loss: 3.3902 - categorical_accuracy: 0.4351 - top_2_accuracy: 0.8040 - top_3_accuracy: 0.9501
# Epoch 7: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 927s 287ms/step - loss: 3.3902 - categorical_accuracy: 0.4351 - top_2_accuracy: 0.8040 - top_3_accuracy: 0.9501 - val_loss: 1.1043 - val_categorical_accuracy: 0.5309 - val_top_2_accuracy: 0.8322 - val_top_3_accuracy: 0.9630 - lr: 0.0025
# Epoch 8/30
# 3225/3225 [==============================] - ETA: 0s - loss: 3.2522 - categorical_accuracy: 0.4489 - top_2_accuracy: 0.8118 - top_3_accuracy: 0.9580
# Epoch 8: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 3225/3225 [==============================] - 951s 295ms/step - loss: 3.2522 - categorical_accuracy: 0.4489 - top_2_accuracy: 0.8118 - top_3_accuracy: 0.9580 - val_loss: 1.1267 - val_categorical_accuracy: 0.5842 - val_top_2_accuracy: 0.8345 - val_top_3_accuracy: 0.9547 - lr: 0.0025
# Epoch 9/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.9609 - categorical_accuracy: 0.4648 - top_2_accuracy: 0.8319 - top_3_accuracy: 0.9682
# Epoch 9: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 962s 298ms/step - loss: 2.9609 - categorical_accuracy: 0.4648 - top_2_accuracy: 0.8319 - top_3_accuracy: 0.9682 - val_loss: 1.1598 - val_categorical_accuracy: 0.3945 - val_top_2_accuracy: 0.8129 - val_top_3_accuracy: 0.9627 - lr: 0.0012
# Epoch 10/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.8023 - categorical_accuracy: 0.4669 - top_2_accuracy: 0.8382 - top_3_accuracy: 0.9733
# Epoch 10: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 3225/3225 [==============================] - 989s 307ms/step - loss: 2.8023 - categorical_accuracy: 0.4669 - top_2_accuracy: 0.8382 - top_3_accuracy: 0.9733 - val_loss: 1.1441 - val_categorical_accuracy: 0.4355 - val_top_2_accuracy: 0.8217 - val_top_3_accuracy: 0.9647 - lr: 0.0012
# Epoch 11/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.5777 - categorical_accuracy: 0.4935 - top_2_accuracy: 0.8507 - top_3_accuracy: 0.9796
# Epoch 11: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 885s 274ms/step - loss: 2.5777 - categorical_accuracy: 0.4935 - top_2_accuracy: 0.8507 - top_3_accuracy: 0.9796 - val_loss: 1.1232 - val_categorical_accuracy: 0.4916 - val_top_2_accuracy: 0.8305 - val_top_3_accuracy: 0.9670 - lr: 6.2500e-04
# Epoch 12/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.4763 - categorical_accuracy: 0.5025 - top_2_accuracy: 0.8610 - top_3_accuracy: 0.9831
# Epoch 12: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 3225/3225 [==============================] - 812s 252ms/step - loss: 2.4763 - categorical_accuracy: 0.5025 - top_2_accuracy: 0.8610 - top_3_accuracy: 0.9831 - val_loss: 1.2098 - val_categorical_accuracy: 0.4121 - val_top_2_accuracy: 0.8086 - val_top_3_accuracy: 0.9553 - lr: 6.2500e-04
# Epoch 13/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.3692 - categorical_accuracy: 0.5163 - top_2_accuracy: 0.8655 - top_3_accuracy: 0.9852
# Epoch 13: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 966s 299ms/step - loss: 2.3692 - categorical_accuracy: 0.5163 - top_2_accuracy: 0.8655 - top_3_accuracy: 0.9852 - val_loss: 1.1932 - val_categorical_accuracy: 0.4298 - val_top_2_accuracy: 0.8149 - val_top_3_accuracy: 0.9638 - lr: 3.1250e-04
# Epoch 14/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.3081 - categorical_accuracy: 0.5264 - top_2_accuracy: 0.8714 - top_3_accuracy: 0.9868
# Epoch 14: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 3225/3225 [==============================] - 1039s 322ms/step - loss: 2.3081 - categorical_accuracy: 0.5264 - top_2_accuracy: 0.8714 - top_3_accuracy: 0.9868 - val_loss: 1.1471 - val_categorical_accuracy: 0.4768 - val_top_2_accuracy: 0.8371 - val_top_3_accuracy: 0.9661 - lr: 3.1250e-04
# Epoch 15/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.2507 - categorical_accuracy: 0.5317 - top_2_accuracy: 0.8726 - top_3_accuracy: 0.9870
# Epoch 15: val_top_3_accuracy did not improve from 0.96696
# 3225/3225 [==============================] - 889s 276ms/step - loss: 2.2507 - categorical_accuracy: 0.5317 - top_2_accuracy: 0.8726 - top_3_accuracy: 0.9870 - val_loss: 1.1635 - val_categorical_accuracy: 0.4691 - val_top_2_accuracy: 0.8268 - val_top_3_accuracy: 0.9655 - lr: 1.5625e-04
# Epoch 16/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.2088 - categorical_accuracy: 0.5420 - top_2_accuracy: 0.8790 - top_3_accuracy: 0.9882
# Epoch 16: val_top_3_accuracy did not improve from 0.96696
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 3225/3225 [==============================] - 806s 250ms/step - loss: 2.2088 - categorical_accuracy: 0.5420 - top_2_accuracy: 0.8790 - top_3_accuracy: 0.9882 - val_loss: 1.1929 - val_categorical_accuracy: 0.4361 - val_top_2_accuracy: 0.8149 - val_top_3_accuracy: 0.9638 - lr: 1.5625e-04
# Epoch 17/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.1617 - categorical_accuracy: 0.5472 - top_2_accuracy: 0.8793 - top_3_accuracy: 0.9895
# Epoch 17: val_top_3_accuracy improved from 0.96696 to 0.96753, saving model to model.h5
# 3225/3225 [==============================] - 812s 252ms/step - loss: 2.1617 - categorical_accuracy: 0.5472 - top_2_accuracy: 0.8793 - top_3_accuracy: 0.9895 - val_loss: 1.1404 - val_categorical_accuracy: 0.4845 - val_top_2_accuracy: 0.8396 - val_top_3_accuracy: 0.9675 - lr: 7.8125e-05
# Epoch 18/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.1515 - categorical_accuracy: 0.5487 - top_2_accuracy: 0.8819 - top_3_accuracy: 0.9902
# Epoch 18: val_top_3_accuracy did not improve from 0.96753
# 3225/3225 [==============================] - 813s 252ms/step - loss: 2.1515 - categorical_accuracy: 0.5487 - top_2_accuracy: 0.8819 - top_3_accuracy: 0.9902 - val_loss: 1.1423 - val_categorical_accuracy: 0.4865 - val_top_2_accuracy: 0.8391 - val_top_3_accuracy: 0.9667 - lr: 7.8125e-05
# Epoch 19/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.1522 - categorical_accuracy: 0.5485 - top_2_accuracy: 0.8804 - top_3_accuracy: 0.9901
# Epoch 19: val_top_3_accuracy did not improve from 0.96753
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 3225/3225 [==============================] - 808s 251ms/step - loss: 2.1522 - categorical_accuracy: 0.5485 - top_2_accuracy: 0.8804 - top_3_accuracy: 0.9901 - val_loss: 1.1699 - val_categorical_accuracy: 0.4623 - val_top_2_accuracy: 0.8257 - val_top_3_accuracy: 0.9661 - lr: 7.8125e-05
# Epoch 20/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.1501 - categorical_accuracy: 0.5511 - top_2_accuracy: 0.8857 - top_3_accuracy: 0.9900
# Epoch 20: val_top_3_accuracy did not improve from 0.96753
# 3225/3225 [==============================] - 810s 251ms/step - loss: 2.1501 - categorical_accuracy: 0.5511 - top_2_accuracy: 0.8857 - top_3_accuracy: 0.9900 - val_loss: 1.1654 - val_categorical_accuracy: 0.4702 - val_top_2_accuracy: 0.8311 - val_top_3_accuracy: 0.9667 - lr: 3.9062e-05
# Epoch 21/30
# 3225/3225 [==============================] - ETA: 0s - loss: 2.1367 - categorical_accuracy: 0.5511 - top_2_accuracy: 0.8855 - top_3_accuracy: 0.9904
# Epoch 21: val_top_3_accuracy did not improve from 0.96753
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 3225/3225 [==============================] - 808s 250ms/step - loss: 2.1367 - categorical_accuracy: 0.5511 - top_2_accuracy: 0.8855 - top_3_accuracy: 0.9904 - val_loss: 1.1635 - val_categorical_accuracy: 0.4662 - val_top_2_accuracy: 0.8325 - val_top_3_accuracy: 0.9661 - lr: 3.9062e-05
# Epoch 22/30
#   10/3225 [..............................] - ETA: 12:14 - loss: 2.3257 - categorical_accuracy: 0.6000 - top_2_accuracy: 0.9300 - top_3_accuracy: 0.9900

# %%
val_loss,val_cat_acc,val_top_2_acc,val_top_3_acc=\
model.evaluate_generator(test_batches,steps=val_steps)

print('val_loss: ',val_loss)
print('val_cat_acc: ',val_cat_acc)
print('val_top_2_acc: ',val_top_2_acc)
print('val_top_3_acc: ',val_top_3_acc)

# %%
model.load_weights('model.h5')

# %%
#checking again after loading our weights
val_loss,val_cat_acc,val_top_2_acc,val_top_3_acc=\
model.evaluate_generator(test_batches,steps=val_steps)

print('val_loss: ',val_loss)
print('val_cat_acc: ',val_cat_acc)
print('val_top_2_acc: ',val_top_2_acc)
print('val_top_3_acc: ',val_top_3_acc)

# %%
predictions=model.predict_generator(test_batches,steps=val_steps,verbose=1)

# %%
from sklearn.metrics import confusion_matrix
import itertools
test_labels=test_batches.classes

# %%
def plot(cm,classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
    if normalize:
        cm=cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
        print('Normalized Confusion Matrix')
    else:
        print('CM without normalization')
    print(cm)
    
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=45)
    plt.yticks(tick_marks,classes)
    
    fmt='.2f' if normalize else 'd'
    thresh=cm.max()/2.
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,format(cm[i,j],fmt),
                horizontalalignment="center",
                color="white" if cm[i,j]>thresh else "black")
    
    plt.xlabel('True label')
    plt.ylabel('Predicted label')
    plt.tight_layout()

cm=confusion_matrix(test_labels,predictions.argmax(axis=1))
cm_plot_labels=['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']
plot(cm,cm_plot_labels)

# %% [markdown]
# ## Deployment

# %%
# %%writefile app.py
import tensorflow as tf
import streamlit as st


@st.cache(allow_output_mutation=True)
def load_model():
  model=tf.keras.models.load_model('model.h5',compile=False)
  return model
with st.spinner('Model is being loaded..'):
  model=load_model()

st.write("""
         # Diabetic Retinopathy Classification
         """
         )

file = st.file_uploader("Please upload an brain scan file", type=["jpg", "png","jpeg"])
import cv2
from PIL import Image, ImageOps
import numpy as np
st.set_option('deprecation.showfileUploaderEncoding', False)
def import_and_predict(image_data, model):
    
        size = (224,224)    
        image = ImageOps.fit(image_data, size, Image.ANTIALIAS)
        image = np.asarray(image)
        img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #img_resize = (cv2.resize(img, dsize=(75, 75),    interpolation=cv2.INTER_CUBIC))/255.
        
        img_reshape = img[np.newaxis,...]
    
        prediction = model.predict(img_reshape)
        
        return prediction
if file is None:
    st.text("Please upload an image file")
else:
    image = Image.open(file)
    st.image(image, use_column_width=True)
    predictions = import_and_predict(image, model)
    score = tf.nn.softmax(predictions[0])
    st.write(predictions)
    st.write(score)
    class_names=['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']
    print("This person most likely has {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score)))
# Out:
# Overwriting app.py

# %%
! streamlit run app.py
# Out:
# ^C
